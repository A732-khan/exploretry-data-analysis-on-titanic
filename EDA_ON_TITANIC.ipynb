# %% [markdown]
# eda
#
# `
# 1>>analysis
# 2>>>feature enginering
# 3>>handling outliers
# ```

# %% [markdown]
# the entire process is highly itrative

# %% [markdown]
# eda k steps ko hum bar bar karga matlab ak bar hum na ak
#
# kaam kya pir dobra information nikal na k leya ya kissi aur k sath iska comparsion karna k leya hum karta hai

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/tested.csv')

# %% [markdown]
# how the data looks like

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# how the looks of our data columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# check mising value

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull().sum().to_frame())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull().sum().to_frame(),cbar=False)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
df.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# conclusion
#
# ```
# missing values in 2 columns one is AGE and second is EMBARKED
# in age  87 missng value
#
# in cabin is more then 70% is missing values
# ```

# %% [markdown]
# drop the cabin columnsa

# %%
df.drop(columns=['Cabin'],inplace=True)

# %% [markdown]
# impute missing value

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-694922604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)
# Out:
# /tmp/ipython-input-1527141296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(),inplace=True)

# %% [markdown]
# now we check the more columns

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: count, dtype: int64

# %% [markdown]
# conclusion
#
# ```
# ab matlab 283 log asa hai jo akala safar kar rah tha
# aur 110 log asay hai jin k sath koi 1 tha
# aur 14 log asa tha jin k sath 2 log aur tha
# ```

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: count, dtype: int64

# %% [markdown]
# conclusion
#
# ab 324 asa log tha jo akla tha
#
# aur 52 asa log tha jin k sath ka koi bata ya baap tha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# ab hun in catgry change karta hai

# %%
df['Survived']=df['Survived'].astype('category')
df['Pclass']=df['Pclass'].astype('category')
df['Sex']=df['Sex'].astype('')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipython-input-3163789335.py in <cell line: 0>()
#       2 df['Pclass']=df['Pclass'].astype('category')
#       3 df['Sex']=df['Sex'].astype('category')
# ----> 4 df['Age']=df['Age'].astype('int')
#       5 df[' Embarked ']=df[' Embarked '].astype('category')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
# ...
